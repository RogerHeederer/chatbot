# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/RogerHeederer/ChatBot/personaGPT_Michigan')

# %%
# !pip install transformers torch
# !pip install -U python-dotenv
# Out:
# ...
#      |████████████████████████████████| 1.3MB 13.4MB/s
# ...
#      |████████████████████████████████| 890kB 16.9MB/s
# ...
#      |████████████████████████████████| 1.1MB 60.8MB/s
# ...
#      |████████████████████████████████| 2.9MB 58.7MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=6968c406a15809e9422794c8dcbd9a19f0b830c52321cadb1e9518e837ff888f
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
# !python3 '/content/drive/MyDrive/RogerHeederer/ChatBot/personaGPT_Michigan/train.py'
# Out:
# 2020-11-30 15:30:27.705065: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# **************************************************
# Load from checkpoint
# Can't load tokenizer for '/content/drive/MyDrive/RogerHeederer/ChatBot/personaGPT_Michigan/save_path/checkpoint/model/'. Make sure that:
#
# - '/content/drive/MyDrive/RogerHeederer/ChatBot/personaGPT_Michigan/save_path/checkpoint/model/' is a correct model identifier listed on 'https://huggingface.co/models'
#
# - or '/content/drive/MyDrive/RogerHeederer/ChatBot/personaGPT_Michigan/save_path/checkpoint/model/' is the correct path to a directory containing relevant tokenizer files
#
#
# **************************************************
# Load from pretrained
# **************************************************
# New Training ...
# Re-sizing model ...
# ...

# %%
# !python3 '/content/drive/MyDrive/RogerHeederer/ChatBot/personaGPT_Michigan/interact.py'
# Out:
# 2020-11-30 17:16:52.040521: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# **************************************************
# Load from checkpoint
# **************************************************
# >> Fact 1: I am a chatbot
# >> Fact 2: I like play tennis
# >> Fact 3: I love a beer
# >> Fact 4: I enjoy swimming
# >> Fact 5: I want to be a doctor
# >> User: hello, how are you
# Bot: hey, i'm good, how are you?
# >> User: I am good too. Do you like playing tennis?
# Bot: i don't know, it is hard for me to find a good place to play
# >> User: What do you do for fun?
# Bot: i like to watch tv
# >> User: Do you like to drink beer while watching tv?
# Bot: no, i like to swim
# >> User: do you like to drink beer?
# Bot: yeah, it keeps my mind off work
# >> User: What do you usually spend on the weekends?
# Bot: watching tv and eating food
# >> User: what kind of food do you like?
# ...
