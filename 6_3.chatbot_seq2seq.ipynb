# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# 훈련 데이터, 데이터 로더, 파이썬 파일 등을 불러오기 위해 경로 설정
import sys
sys.path.append('gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer')

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.4MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/fd/96/1030895dea70855a2e1078e3fe0d6a63dcb7c212309e07dc9ee39d33af54/JPype1-1.1.2-cp36-cp36m-manylinux2010_x86_64.whl (450kB)
#      |████████████████████████████████| 460kB 58.6MB/s
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 8.9MB/s
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/bb/7c/99d51f80f3b77b107ebae2634108717362c059a41384a1810d13e2429a81/tweepy-3.9.0-py2.py3-none-any.whl
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Installing collected packages: JPype1, colorama, beautifulsoup4, tweepy, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# Successfully installed JPype1-1.1.2 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2 tweepy-3.9.0

# %%
import tensorflow as tf
import numpy as np
import os

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from preprocess import *

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string], '')
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %% [markdown]
# 학습 데이터 경로 정의

# %%
BASE_PATH = '/content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer'
DATA_IN_PATH = BASE_PATH + '/data_in/'
DATA_OUT_PATH = BASE_PATH + '/data_out/'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

# %%
SEED_NUM = 1234
tf.random.set_seed(SEED_NUM)

# %% [markdown]
# 파일 로드

# %%
index_inputs = np.load(open(DATA_IN_PATH + TRAIN_INPUTS, 'rb'))
index_outputs = np.load(open(DATA_IN_PATH + TRAIN_OUTPUTS , 'rb'))
index_targets = np.load(open(DATA_IN_PATH + TRAIN_TARGETS , 'rb'))
prepro_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))

# %%
print(len(index_inputs), len(index_outputs), len(index_targets))
# Out:
# 11823 11823 11823

# %% [markdown]
# 모델 만들기에 필요한 파라미터들 선언

# %%
MODEL_NAME = 'seq2seq_kor'
BATCH_SIZE = 2
MAX_SEQUENCE = 25
EPOCH = 30
UNITS = 1024
EMBEDDING_DIM = 256
VALIDATION_SPLIT = 0.1 

char2idx = prepro_configs['char2idx']
idx2char = prepro_configs['idx2char']
std_index = prepro_configs['std_symbol']
end_index = prepro_configs['end_symbol']
vocab_size = prepro_configs['vocab_size']

# %% [markdown]
# ##인코더##

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.vocab_size = vocab_size
    self.embedding_dim = embedding_dim

    self.embedding = tf.keras.layers.Embedding(self.vocab_size, self.embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    
  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return output, state

  def initialize_hidden_state(self, inp):
    return tf.zeros((tf.shape(inp)[0], self.enc_units))

# %% [markdown]
# ##어텐션

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    hidden_with_time_axis = tf.expand_dims(query, 1)

    score = self.V(tf.nn.tanh(self.W1(values) + self.W2(hidden_with_time_axis)))

    attention_weights = tf.nn.softmax(score, axis=1)

    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %% [markdown]
# ##디코더##

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.vocab_size = vocab_size 
        self.embedding_dim = embedding_dim  
        
        self.embedding = tf.keras.layers.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(self.vocab_size)

        self.attention = BahdanauAttention(self.dec_units)
        
    def call(self, x, hidden, enc_output):
        context_vector, attention_weights = self.attention(hidden, enc_output)

        x = self.embedding(x)

        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        output, state = self.gru(x)
        output = tf.reshape(output, (-1, output.shape[2]))
            
        x = self.fc(output)
        
        return x, state, attention_weights

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')

def loss(real, pred): #인자로 정답과 예측값을 받아서
   #real 값 중 0인값(<PAD>)와 비교, real 값이 0(PAD) 이면 True 반환/ 아니면 False
   #logical_not을 먹여서 0은 1로  1은 0으로 변경
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred) #로쓰를 계산하고
  mask = tf.cast(mask, dtype=loss_.dtype) 
  loss_ *= mask # <pad>는 손실 계산에서 뺀다.
  return tf.reduce_mean(loss_)

def accuracy(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  mask = tf.expand_dims(tf.cast(mask, dtype=pred.dtype), axis=-1)
  pred *= mask
  acc = train_accuracy(real, pred)

  return tf.reduce_mean(acc)

# %% [markdown]
# ##Seq To Seq 모델##
#
# 각각 분리돼 있는 위 클래스들을 이어주는 메인 클래스

# %%
class seq2seq(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, dec_units, batch_sz, end_token_idx=2):
    super(seq2seq, self).__init__()
    self.end_token_idx = end_token_idx
    self.encoder = Encoder(vocab_size, embedding_dim, enc_units, batch_sz)
    self.decoder = Decoder(vocab_size, embedding_dim, dec_units, batch_sz)

  def call(self, x):
    inp, tar = x

    enc_hidden = self.encoder.initialize_hidden_state(inp)
    enc_output, enc_hidden = self.encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    predict_tokens = list()
    for t in range(0, tar.shape[1]):
      dec_input = tf.dtypes.cast(tf.expand_dims(tar[:, t], 1), tf.float32)
      predictions, dec_hidden, _= self.decoder(dec_input, dec_hidden, enc_output)
      predict_tokens.append(tf.dtypes.cast(predictions, tf.float32))
    return tf.stack(predict_tokens, axis=1)
    
  def inference(self, x): #사용자의 입력에 대한 모델의 결과값을 확인하기 위해 테스트 목적 함수
    inp = x

    enc_hidden = self.encoder.initialize_hidden_state(inp)
    enc_output, enc_hidden = self.encoder(inp, enc_hidden)
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([char2idx[std_index]], 1)

    predict_tokens = list()
    for t in range(0, MAX_SEQUENCE):
      predictions, dec_hidden, _ = self.decoder(dec_input, dec_hidden, enc_output)
      predict_token = tf.argmax(predictions[0])

      if predict_token == self.end_token_idx:
        break

      predict_tokens.append(predict_token)
      dec_input = tf.dtypes.cast(tf.expand_dims([predict_token], 0), tf.float32)

    return tf.stack(predict_tokens, axis=0).numpy()

# %%
model = seq2seq(vocab_size, EMBEDDING_DIM, UNITS, UNITS, BATCH_SIZE, char2idx[end_index])
model.compile(loss=loss, optimizer=tf.keras.optimizers.Adam(1e-3), metrics=[accuracy])

# %%
PATH = DATA_OUT_PATH + MODEL_NAME
if not(os.path.isdir(PATH)):
        os.makedirs(os.path.join(PATH))
        
checkpoint_path = DATA_OUT_PATH + MODEL_NAME + '/weights.h5'
    
cp_callback = ModelCheckpoint(
    checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True)

earlystop_callback = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=10)

history = model.fit([index_inputs, index_outputs], index_targets,
                    batch_size=BATCH_SIZE, epochs=EPOCH,
                    validation_split=VALIDATION_SPLIT, callbacks=[earlystop_callback, cp_callback])

model.save(filepath = '/content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/', save_format="tf")
# Out:
# Epoch 1/30
# 5320/5320 [==============================] - ETA: 0s - loss: 1.4500 - accuracy: 0.8118
# Epoch 00001: val_accuracy improved from -inf to 0.80997, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 701s 132ms/step - loss: 1.4500 - accuracy: 0.8118 - val_loss: 1.6427 - val_accuracy: 0.8100
# Epoch 2/30
# 5320/5320 [==============================] - ETA: 0s - loss: 1.2418 - accuracy: 0.8130
# Epoch 00002: val_accuracy improved from 0.80997 to 0.81580, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 680s 128ms/step - loss: 1.2418 - accuracy: 0.8130 - val_loss: 1.6179 - val_accuracy: 0.8158
# Epoch 3/30
# 5320/5320 [==============================] - ETA: 0s - loss: 1.0801 - accuracy: 0.8194
# Epoch 00003: val_accuracy improved from 0.81580 to 0.82255, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 668s 126ms/step - loss: 1.0801 - accuracy: 0.8194 - val_loss: 1.6245 - val_accuracy: 0.8225
# Epoch 4/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.9260 - accuracy: 0.8259
# Epoch 00004: val_accuracy improved from 0.82255 to 0.82894, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 669s 126ms/step - loss: 0.9260 - accuracy: 0.8259 - val_loss: 1.6687 - val_accuracy: 0.8289
# Epoch 5/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.7651 - accuracy: 0.8324
# Epoch 00005: val_accuracy improved from 0.82894 to 0.83548, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 669s 126ms/step - loss: 0.7651 - accuracy: 0.8324 - val_loss: 1.7489 - val_accuracy: 0.8355
# Epoch 6/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.6064 - accuracy: 0.8393
# Epoch 00006: val_accuracy improved from 0.83548 to 0.84241, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 669s 126ms/step - loss: 0.6064 - accuracy: 0.8393 - val_loss: 1.8792 - val_accuracy: 0.8424
# Epoch 7/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.4752 - accuracy: 0.8463
# Epoch 00007: val_accuracy improved from 0.84241 to 0.84964, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 660s 124ms/step - loss: 0.4752 - accuracy: 0.8463 - val_loss: 2.0311 - val_accuracy: 0.8496
# Epoch 8/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.3850 - accuracy: 0.8535
# Epoch 00008: val_accuracy improved from 0.84964 to 0.85663, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 653s 123ms/step - loss: 0.3850 - accuracy: 0.8535 - val_loss: 2.1556 - val_accuracy: 0.8566
# Epoch 9/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.8601
# Epoch 00009: val_accuracy improved from 0.85663 to 0.86306, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 657s 123ms/step - loss: 0.3252 - accuracy: 0.8601 - val_loss: 2.2727 - val_accuracy: 0.8631
# Epoch 10/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.2879 - accuracy: 0.8662
# Epoch 00010: val_accuracy improved from 0.86306 to 0.86883, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 664s 125ms/step - loss: 0.2879 - accuracy: 0.8662 - val_loss: 2.3808 - val_accuracy: 0.8688
# Epoch 11/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.2586 - accuracy: 0.8715
# Epoch 00011: val_accuracy improved from 0.86883 to 0.87393, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 646s 121ms/step - loss: 0.2586 - accuracy: 0.8715 - val_loss: 2.5006 - val_accuracy: 0.8739
# Epoch 12/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.8764
# Epoch 00012: val_accuracy improved from 0.87393 to 0.87853, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 646s 121ms/step - loss: 0.2326 - accuracy: 0.8764 - val_loss: 2.5002 - val_accuracy: 0.8785
# Epoch 13/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.2057 - accuracy: 0.8808
# Epoch 00013: val_accuracy improved from 0.87853 to 0.88280, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 651s 122ms/step - loss: 0.2057 - accuracy: 0.8808 - val_loss: 2.5051 - val_accuracy: 0.8828
# Epoch 14/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.1779 - accuracy: 0.8849
# Epoch 00014: val_accuracy improved from 0.88280 to 0.88682, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 642s 121ms/step - loss: 0.1779 - accuracy: 0.8849 - val_loss: 2.5254 - val_accuracy: 0.8868
# Epoch 15/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.8888
# Epoch 00015: val_accuracy improved from 0.88682 to 0.89062, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 648s 122ms/step - loss: 0.1540 - accuracy: 0.8888 - val_loss: 2.6223 - val_accuracy: 0.8906
# Epoch 16/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.8925
# Epoch 00016: val_accuracy improved from 0.89062 to 0.89419, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 645s 121ms/step - loss: 0.1346 - accuracy: 0.8925 - val_loss: 2.6728 - val_accuracy: 0.8942
# Epoch 17/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.8959
# Epoch 00017: val_accuracy improved from 0.89419 to 0.89748, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 641s 121ms/step - loss: 0.1227 - accuracy: 0.8959 - val_loss: 2.7214 - val_accuracy: 0.8975
# Epoch 18/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.8991
# Epoch 00018: val_accuracy improved from 0.89748 to 0.90049, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 646s 121ms/step - loss: 0.1143 - accuracy: 0.8991 - val_loss: 2.7510 - val_accuracy: 0.9005
# Epoch 19/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9019
# Epoch 00019: val_accuracy improved from 0.90049 to 0.90325, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 643s 121ms/step - loss: 0.1066 - accuracy: 0.9019 - val_loss: 2.9679 - val_accuracy: 0.9032
# Epoch 20/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9045
# Epoch 00020: val_accuracy improved from 0.90325 to 0.90574, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 643s 121ms/step - loss: 0.1029 - accuracy: 0.9045 - val_loss: 2.9660 - val_accuracy: 0.9057
# Epoch 21/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9069
# Epoch 00021: val_accuracy improved from 0.90574 to 0.90803, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 665s 125ms/step - loss: 0.1000 - accuracy: 0.9069 - val_loss: 2.8970 - val_accuracy: 0.9080
# Epoch 22/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9091
# Epoch 00022: val_accuracy improved from 0.90803 to 0.91013, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 664s 125ms/step - loss: 0.0963 - accuracy: 0.9091 - val_loss: 2.9590 - val_accuracy: 0.9101
# Epoch 23/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9111
# Epoch 00023: val_accuracy improved from 0.91013 to 0.91204, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 646s 121ms/step - loss: 0.0951 - accuracy: 0.9111 - val_loss: 3.0163 - val_accuracy: 0.9120
# Epoch 24/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9130
# Epoch 00024: val_accuracy improved from 0.91204 to 0.91381, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 653s 123ms/step - loss: 0.0923 - accuracy: 0.9130 - val_loss: 2.9509 - val_accuracy: 0.9138
# Epoch 25/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0897 - accuracy: 0.9147
# Epoch 00025: val_accuracy improved from 0.91381 to 0.91547, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 641s 120ms/step - loss: 0.0897 - accuracy: 0.9147 - val_loss: 3.0096 - val_accuracy: 0.9155
# Epoch 26/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9163
# Epoch 00026: val_accuracy improved from 0.91547 to 0.91700, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 645s 121ms/step - loss: 0.0891 - accuracy: 0.9163 - val_loss: 3.1070 - val_accuracy: 0.9170
# Epoch 27/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0867 - accuracy: 0.9177
# Epoch 00027: val_accuracy improved from 0.91700 to 0.91841, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 643s 121ms/step - loss: 0.0867 - accuracy: 0.9177 - val_loss: 3.1562 - val_accuracy: 0.9184
# Epoch 28/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9191
# Epoch 00028: val_accuracy improved from 0.91841 to 0.91973, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 663s 125ms/step - loss: 0.0863 - accuracy: 0.9191 - val_loss: 3.0484 - val_accuracy: 0.9197
# Epoch 29/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9204
# Epoch 00029: val_accuracy improved from 0.91973 to 0.92095, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 692s 130ms/step - loss: 0.0858 - accuracy: 0.9204 - val_loss: 3.0475 - val_accuracy: 0.9210
# Epoch 30/30
# 5320/5320 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9216
# Epoch 00030: val_accuracy improved from 0.92095 to 0.92211, saving model to /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5
# 5320/5320 [==============================] - 696s 131ms/step - loss: 0.0831 - accuracy: 0.9216 - val_loss: 3.0705 - val_accuracy: 0.9221
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/assets

# %%
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/assets

# %%
SAVE_FILE_NM = "weights.h5"
print(os.path.join(DATA_OUT_PATH, MODEL_NAME, SAVE_FILE_NM))
# Out:
# /content/gdrive/My Drive/RogerHeederer/NLP_KR/6.CHATBOT_heederer/data_out/seq2seq_kor/weights.h5

# %%
model.fit([index_inputs, index_outputs], index_targets,
                    batch_size=BATCH_SIZE, epochs=1)
# Out:
#   58/5912 [..............................] - ETA: 20:51 - loss: 1.8006 - accuracy: 0.8023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-a527842b38c3> in <module>()
#       1 model.fit([index_inputs, index_outputs], index_targets,
# ----> 2                     batch_size=BATCH_SIZE, epochs=1)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.fit([index_inputs, index_outputs], index_targets)
# Out:
# 370/370 [==============================] - 85s 230ms/step - loss: 0.3053 - accuracy: 0.9522

# %% [markdown]
# 모델 웨이트를 로드하기 전에는 model.compile이 된 베이스를 바탕으로 fit을 먼저 해줘야
#
# 모델 웨이트 로딩을 할 수 있는 것 같다

# %%
model.load_weights(os.path.join(DATA_OUT_PATH, MODEL_NAME, SAVE_FILE_NM))

# %%
query = "요즘 잠이 안와"

test_index_inputs, _ = enc_processing([query], char2idx)    
predict_tokens = model.inference(test_index_inputs)
print(predict_tokens)

print(' '.join([idx2char[str(t)] for t in predict_tokens]))
# Out:
# [ 4290 13858 11647  1976 15501  1274]
# 계속 좋지 않으면 병원 에가 보세요
