# %% [markdown]
# <a href="https://colab.research.google.com/github/RogerHeederer/chatbot/blob/master/UsingColabWithConda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##코랩에서 아나콘다 패키지 사용하기##

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version

#구글 코랩에 디폴트로 깔려 있는 python 3.6과 매칭이 되는 미니콘다를 깔아야 함
#그 미니콘다 버전은 4.5.4
# Out:
# Python 3.6.9

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
#PYTHONPATH를 unset해야한다. 
#위에 처럼 세팅된 디렉토리로 놔두면, 접근 에러가 발생할 수 있다.
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %% [markdown]
# ##Miniconda 설치##

# %%
# %%bash
#
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version
# Out:
# conda 4.5.4

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
#미니 콘다가 설치된 후에는 파이썬 버젼이 살짝 바뀜
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %% [markdown]
# ##아나콘다 버전 업데이트##

# %%
# Without 파이썬 업데이트, 아나콘다 최신 버젼으로 업데이트
# 즉 파이썬은 3.6버전으로 홀딩하고, 아나콘다 업데이트
# %%bash

conda install --channel defaults conda python=3.6 --yes
conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libedit-3.1.20191231       |       h14c3975_1         121 KB
#     sqlite-3.33.0              |       h62c20be_0         2.0 MB
#     conda-package-handling-1.7.2|   py36h03888b9_0         967 KB
#     urllib3-1.25.11            |             py_0          93 KB
#     pyopenssl-19.1.0           |     pyhd3eb1b0_1          52 KB
#     cryptography-3.2.1         |   py36h3c74f83_1         631 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     wheel-0.35.1               |     pyhd3eb1b0_0          37 KB
#     chardet-3.0.4              |py36h06a4308_1003         197 KB
#     conda-4.9.2                |   py36h06a4308_0         3.1 MB
# ...

# %%
# !conda --version
# Out:
# conda 4.9.2

# %%
# !python --version
# Out:
# Python 3.6.12 :: Anaconda, Inc.

# %% [markdown]
# ##시스템 패스 설정##
#
# 아나콘다 설치는 끝났고, 아나콘다가 관련 패키지를 설치할 수 있는 디렉토리를 정해줘야함 (이 디렉토리는 파이썬이 서치하거나, 모듈을 import할 디렉토리)

# %%
import sys
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.6/dist-packages
# Out:
# absl
# absl_py-0.10.0.dist-info
# alabaster
# alabaster-0.7.12.dist-info
# albumentations
# albumentations-0.1.12.dist-info
# altair
# altair-4.1.0.dist-info
# apiclient
# argon2
# argon2_cffi-20.1.0.dist-info
# asgiref
# asgiref-3.3.0.dist-info
# astor
# astor-0.8.1.dist-info
# astropy
# astropy-4.1.dist-info
# astunparse
# astunparse-1.6.3.dist-info
# async_generator
# async_generator-1.10.dist-info
# atari_py
# atari_py-0.2.6.dist-info
# atomicwrites
# atomicwrites-1.4.0.dist-info
# attr
# attrs-20.2.0.dist-info
# audioread
# audioread-2.1.9.dist-info
# autograd
# autograd-1.3.dist-info
# babel
# Babel-2.8.0.dist-info
# backcall
# backcall-0.2.0.dist-info
# beautifulsoup4-4.6.3.dist-info
# bin
# bleach
# bleach-3.2.1.dist-info
# blis
# blis-0.4.1.dist-info
# bokeh
# bokeh-2.1.1.dist-info
# bottleneck
# Bottleneck-1.3.2.dist-info
# branca
# branca-0.4.1.dist-info
# bs4
# bs4-0.0.1.dist-info
# bson
# cachecontrol
# CacheControl-0.12.6.dist-info
# cachetools
# ...

# %%
# Any package that you install with Conda will be installed into the directory
import sys
_ = (sys.path.append("/usr/local/lib/python3.6/site-packages"))

# %%
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/usr/local/lib/python3.6/site-packages']

# %%
#site-packages 가 제일 아래 붙었다.
#구글 코랩에 디폴트로 인스톨 된 패키지인 dist-packages가 먼저 나타난다. 
#그래서 구글 코랩에 의해 가능한 패키지 버젼이 콘다를 통해 깔린 같은 패키지의 어떤 버젼보다 우선할 수 있다. 선점할 수 있다.
#코랩 패키지 버젼이 우위를 가진다

# %% [markdown]
# ##패키지 인스톨하기##

# %%
# !conda install --channel conda-forge featuretools --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - featuretools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-2.2.3                |   py36h9f0ad1d_0         7.0 MB  conda-forge
#     ca-certificates-2020.11.8  |       ha878542_0         145 KB  conda-forge
#     certifi-2020.11.8          |   py36h5fab9bb_0         150 KB  conda-forge
#     click-7.1.2                |     pyh9f0ad1d_0          64 KB  conda-forge
#     cloudpickle-1.6.0          |             py_0          22 KB  conda-forge
#     conda-4.9.2                |   py36h5fab9bb_0         3.0 MB  conda-forge
#     contextvars-2.4            |             py_0          11 KB  conda-forge
#     cytoolz-0.11.0             |   py36h8c4c3a4_1         371 KB  conda-forge
# ...

# %%
# !ls
# Out:
# drive  Miniconda3-4.5.4-Linux-x86_64.sh  sample_data

# %%
# !conda env create -f /content/drive/MyDrive/RogerHeederer/ChatBot/KoGPT2-personachat-master/environment.yml
# Out:
# done
# done
#
# ...
# wcwidth-0.2.5        | 29 KB     | : 100% 1.0/1 [00:00<00:00,  7.00it/s]
# pysocks-1.7.1        | 27 KB     | : 100% 1.0/1 [00:00<00:00, 10.06it/s]
# tensorflow-2.2.0     | 4 KB      | : 100% 1.0/1 [00:00<00:00,  4.00it/s]
# rsa-4.6              | 26 KB     | : 100% 1.0/1 [00:00<00:00, 10.34it/s]
# jupyter_client-6.1.6 | 84 KB     | : 100% 1.0/1 [00:00<00:00,  4.67it/s]
# ipykernel-5.3.4      | 179 KB    | : 100% 1.0/1 [00:00<00:00,  9.21it/s]
# ipython_genutils-0.2 | 39 KB     | : 100% 1.0/1 [00:00<00:00,  9.92it/s]
# pytorch-1.6.0        | 515.9 MB  | : 100% 1.0/1 [02:16<00:00, 136.29s/it]
# libsodium-1.0.18     | 244 KB    | : 100% 1.0/1 [00:00<00:00,  8.68it/s]
# jedi-0.17.2          | 912 KB    | : 100% 1.0/1 [00:00<00:00,  2.85it/s]
# packaging-20.4       | 36 KB     | : 100% 1.0/1 [00:00<00:00,  9.87it/s]
# werkzeug-1.0.1       | 240 KB    | : 100% 1.0/1 [00:00<00:00,  9.17it/s]
# libgfortran-ng-7.3.0 | 1006 KB   | : 100% 1.0/1 [00:00<00:00,  7.56it/s]
# ...

# %%
# %%shell
# $conda activate cm

# %%
# %%shell
# conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# cm                       /usr/local/envs/cm
