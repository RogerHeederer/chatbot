# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls drive/'My Drive'/'RogerHeederer'/'ChatBot'/'KoGPT2_Wellness'/'preprocess'
# Out:
# preprocess.ipynb  training_data.py

# %%
# !python3 '/content/drive/My Drive/RogerHeederer/ChatBot/KoGPT2_Wellness/preprocess/training_data.py'
