# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -r 'drive/My Drive/RogerHeederer/ChatBot/KoGPT2_Wellness/requirements.txt'
# Out:
# ...
#      |████████████████████████████████| 778kB 11.0MB/s
# ...
#      |████████████████████████████████| 2.9MB 23.0MB/s
# ...
#      |████████████████████████████████| 890kB 48.0MB/s
# ...
#      |████████████████████████████████| 1.1MB 44.2MB/s
# ...
#      |████████████████████████████████| 51kB 8.2MB/s
# ...
#   Created wheel for kss: filename=kss-1.3.1-cp36-cp36m-linux_x86_64.whl size=251576 sha256=1312d8bd068ef534b895a490c8673aefd922c246d48b90061eec3cd32857df37
#   Stored in directory: /root/.cache/pip/wheels/8b/98/d1/53f75f89925cd95779824778725ee3fa36e7aa55ed26ad54a8
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=c92445e80b920599a942a0f661ddc69221965aa56cbe67eb13d3418c6874432f
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built kss sacremoses
# ERROR: transformers 3.0.2 has requirement tokenizers==0.8.1.rc1, but you'll have tokenizers 0.9.4 which is incompatible.
# ...

# %%
# !pip uninstall tokenizers
# Out:
# Uninstalling tokenizers-0.9.4:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/tokenizers-0.9.4.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tokenizers/*
# Proceed (y/n)? y
#   Successfully uninstalled tokenizers-0.9.4

# %%
# !pip install tokenizers==0.8.1.rc1
# Out:
# ...
#      |████████████████████████████████| 3.0MB 8.2MB/s
# ...

# %%
input()
# Out:
# !python3
# '!python3'

# %%
input() = !python3 '/content/drive/My Drive/RogerHeederer/ChatBot/KoGPT2_Wellness/run/kogpt2-text-generation.py'
# Out:
#   File "<ipython-input-13-643dae7e955d>", line 1
#     input() = !python3 '/content/drive/My Drive/RogerHeederer/ChatBot/KoGPT2_Wellness/run/kogpt2-text-generation.py'
#               ^
# SyntaxError: invalid syntax

# %%
# !python3 '/content/drive/My Drive/RogerHeederer/ChatBot/KoGPT2_Wellness/run/kogpt2-text-generation.py'
# Out:
# 2020-11-10 08:27:52.805022: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# drive/My Drive/RogerHeederer/ChatBot/KoGPT2_Wellness/checkpoint/total_autoregressive.pth
# Question: 부정적인 생각이 많이 드네
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# Answer: 부정적인 생각 많이 드는 거 같아요부정적인 생각을 하게 돼요부정적인 생각을 하게 되면 아무 것도 할 수 없어요부정적인 생각을 하게 되지요부정적인 생각을 하게 되지 마세요부정적인 생각을 하게 되지 않는 한
# ----------------------------------------------------------------------------------------------------
# Question: 사고 후유증이 있는걸까
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# Answer: 치료는 스무 살 때 시작했어요마음을 다잡는게 중요해요아프지 않은 이별을 위해 노력해보세요아쉬운 게 당연하죠아휴렛대로 이별을 설계해보세요아쉬운 게
# ----------------------------------------------------------------------------------------------------
# Question: 화가 많이 날 때는 감정 조절이 안된다
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# ...
